# %%
import pandas as pd
from statsmodels.tsa.seasonal import STL
from sklearn.linear_model import LinearRegression

# %%
# Load the CSV data into a Pandas DataFrame
df = pd.read_csv('ZIL.csv')

# %%
# Extract just the dates and prices
data = df[['dates', 'prices']]

# %%
# Convert dates to datetime
data['dates'] = pd.to_datetime(data['dates'])
# Out:
# <ipython-input-7-457d556d7f19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['dates'] = pd.to_datetime(data['dates'])

# %%
# Set the index to be the datetime
data = data.set_index('dates')

# %%
data = data.resample('D').mean()

# %%
data = data.interpolate()

# %%
data = data.dropna()

# %%
prices = data['prices']
res = STL(prices).fit()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from statsmodels.tsa.seasonal import STL

# Load cryptocurrency price data
df = pd.read_csv('ZIL.csv')

# Select ZIL prices
zil = df['prices']

# Decompose time series using STL

t = res.trend
s = res.seasonal
r = res.resid

# Use decomposed trend component in linear regression
X = t.index.values.reshape(-1,1)
y = t.values

model = LinearRegression()
model.fit(X, y)

# Make predictions
X_test = [[value] for value in t.index[-30:]]


# Evaluate model performance


print('Coefficients:', model.coef_)
# Plot original time series
plt.plot(df['dates'], zil, 'b-', label='Original')



# Plot outliers
outliers = zil[abs(zil - zil.mean()) > 3*zil.std()]
plt.scatter(outliers.index, outliers.values, color='black', label='Outliers')

plt.legend()
plt.xlabel('Date')
plt.ylabel('ZIL Price')
plt.title('ZIL Prices - Original vs Predicted')

plt.show()
# Out:
# Coefficients: [-1.24587182e-18]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from statsmodels.tsa.seasonal import STL

# Load cryptocurrency price data
df = pd.read_csv('SOL.csv')

# Select SOL prices
sol = df['prices']

# Decompose time series using STL

t = res.trend
s = res.seasonal
r = res.resid

# Use decomposed trend component in linear regression
X = t.index.values.reshape(-1,1)
y = t.values

model = LinearRegression()
model.fit(X, y)

# Make predictions
X_test = [[value] for value in t.index[-30:]]

# Evaluate model performance
print('Coefficients:', model.coef_)

# Plot original time series
plt.plot(df['dates'], sol, 'b-', label='Original')

# Plot outliers
outliers = sol[abs(sol - sol.mean()) > 3*sol.std()]
plt.scatter(outliers.index, outliers.values, color='black', label='Outliers')

plt.legend()
plt.xlabel('Date')
plt.ylabel('SOL Price')
plt.title('SOL Prices - Original vs Predicted')
plt.show()
# Out:
# Coefficients: [-1.24587182e-18]

# %%
import pandas as pd

# Previous code to load data, build model, make predictions
def make_predictions():

    # Do some calculations here
    return predictions

predictions = make_predictions()
# Print last 30 original values
print('Original Values:')
print(zil.values[-30:])

# Print predicted values

print(predictions)

# Detect and print outliers
outliers = zil[abs(zil - zil.mean()) > 3*zil.std()]
print('\nOutliers:')
print(outliers.values)
# Out:
# Original Values:
# [0.03145809 0.03097633 0.02951931 0.02977293 0.0302968  0.0294573
#  0.02910029 0.02924945 0.02927651 0.02966291 0.02970013 0.02917692
#  0.0298684  0.03067019 0.03080415 0.03222318 0.03152831 0.03356253
#  0.03181725 0.03014676 0.03098246 0.03485816 0.03227145 0.03108298
#  0.03024113 0.02910601 0.0291968  0.02889816 0.02884054 0.02821859]
# []
#
# Outliers:
# [0.18179684 0.17732357 0.18207014 0.16555423 0.15337477 0.14062078
#  0.12446776 0.13126289 0.13344983 0.11990412 0.12082236 0.1203625
#  0.12651512]
